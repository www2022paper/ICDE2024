# %% [markdown]
# ## Fig (a) and aucc value

# %%
# output pic

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# read input csv ==================
direct_ratio_SL_aucc_list = pd.read_csv("../figure/A_direct_ratio_SL_aucc_list.csv")
direct_ratio_XL_aucc_list = pd.read_csv("../figure/A_direct_ratio_XL_aucc_list.csv")

grf = pd.read_csv("../figure/A_grf_aucc_list.csv")

dr = pd.read_csv("../figure/a_DR_avg_aucc_cost_curve_1.0.csv")
dr_mc = pd.read_csv("../figure/a_DR_MC_avg_aucc_cost_curve_1.0.csv")

DRP_avg_aucc_cost_curve = pd.read_csv("../figure/DRP_avg_aucc_cost_curve_1.0.csv")
drp_mc = pd.read_csv("../figure/a_DRP_MC_avg_aucc_cost_curve_1.0.csv")


rDRP_avg_aucc_cost_curve = pd.read_csv("../figure/rDRP_avg_aucc_cost_curve_1.0.csv")


# cal aucc =================
SL_aucc = np.sum(direct_ratio_SL_aucc_list['delta_reward'].values) / (direct_ratio_SL_aucc_list['delta_reward'].values[-1] * 201)
XL_aucc = np.sum(direct_ratio_XL_aucc_list['delta_reward'].values) / (direct_ratio_XL_aucc_list['delta_reward'].values[-1] * 201)
GRF_aucc = np.sum(grf['delta_reward'].values) / (grf['delta_reward'].values[-1] * 201)


DR_aucc = np.sum(dr['delta_reward'].values) / (dr['delta_reward'].values[-1] * 201)
DR_MC_aucc = np.sum(dr_mc['delta_reward'].values) / (dr_mc['delta_reward'].values[-1] * 201)


DRP_aucc = np.sum(DRP_avg_aucc_cost_curve['delta_reward'].values) / (DRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)
DRP_MC_aucc = np.sum(drp_mc['delta_reward'].values) / (drp_mc['delta_reward'].values[-1] * 201)

rDRP_aucc = np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)


# output data results ================

print(f"TPM-SL: {SL_aucc:.4f}")
print(f"TPM-XL: {XL_aucc:.4f}")
print(f"TPM-CF: {GRF_aucc:.4f}")


print(f"DR: {DR_aucc:.4f}")
print(f"DR_MC: {DR_MC_aucc:.4f}")


print(f"DRP: {DRP_aucc:.4f}")
print(f"DRP_MC: {DRP_MC_aucc:.4f}")

print(f"rDRP: {rDRP_aucc:.4f}")
# improve = 100*(rDRP_aucc - DRP_aucc)/DRP_aucc
# print(f"{improve:.2f}%")

# np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)

x_index = DRP_avg_aucc_cost_curve['delta_cost'].values
y_random = DRP_avg_aucc_cost_curve['delta_reward'].values[-1] / x_index[-1] * x_index

x_normalization = x_index[-1]
y_normalization = DRP_avg_aucc_cost_curve['delta_reward'].values[-1]


# random ===================================
plt.plot(x_index / x_normalization, y_random / y_normalization, color='#000000', label='Random', linewidth=1.5)

# TPM-SL
plt.plot(x_index / x_normalization, direct_ratio_SL_aucc_list['delta_reward'].values / y_normalization, color='#1f77b4', label='TPM-SL', linewidth=1.5)


# TPM-XL
plt.plot(x_index / x_normalization, direct_ratio_XL_aucc_list['delta_reward'].values / y_normalization, color='#808000', label='TPM-XL', linewidth=1.5)


# TPM-CF
plt.plot(x_index / x_normalization, grf['delta_reward'].values / y_normalization, color='#800080', label='TPM-CF', linewidth=1.5)


# DR
plt.plot(x_index / x_normalization, dr['delta_reward'].values / y_normalization, color='#d62728', label='DR', linewidth=1.5)

# DR_MC
plt.plot(x_index / x_normalization, dr_mc['delta_reward'].values / y_normalization, color='#17becf', label='DR-MC', linewidth=1.5)


# DRP
plt.plot(x_index / x_normalization, DRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#FBB454', label='DRP', linewidth=1.5)


# DRP_MC
plt.plot(x_index / x_normalization, drp_mc['delta_reward'].values / y_normalization, color='#e377c2', label='DRP-MC', linewidth=1.5)


# rDPR
plt.plot(x_index / x_normalization, rDRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#40a368', label='rDRP', linewidth=1.5)


plt.title('Sufficient data and No covariate shift')


plt.xlabel('Incremental cost', fontsize=12, fontweight='bold')
plt.ylabel('Incremental reward', fontsize=12, fontweight='bold')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend()
plt.grid(True)
plt.tight_layout()


# Save and display the figure

plt.savefig('../figure/a.pdf', format='pdf', bbox_inches = 'tight')
plt.show()
# Out:
# TPM-SL: 0.6983
# TPM-XL: 0.5965
# TPM-CF: 0.7034
# DR: 0.7474
# DR_MC: 0.7464
# DRP: 0.7714
# DRP_MC: 0.7716
# rDRP: 0.7717

# %% [markdown]
# ## Fig (b) and aucc value

# %%
# output pic

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# read input csv ==================
direct_ratio_SL_aucc_list = pd.read_csv("../figure/B_direct_ratio_SL_aucc_list.csv")
direct_ratio_XL_aucc_list = pd.read_csv("../figure/B_direct_ratio_XL_aucc_list.csv")

grf = pd.read_csv("../figure/B_grf_aucc_list.csv")

dr = pd.read_csv("../figure/b_DR_avg_aucc_cost_curve_1.0.csv")
dr_mc = pd.read_csv("../figure/b_DR_MC_avg_aucc_cost_curve_1.0.csv")

DRP_avg_aucc_cost_curve = pd.read_csv("../figure/DRP_avg_aucc_cost_curve_1.0_shift.csv")
drp_mc = pd.read_csv("../figure/b_DRP_MC_avg_aucc_cost_curve_1.0_shift.csv")


rDRP_avg_aucc_cost_curve = pd.read_csv("../figure/rDRP_avg_aucc_cost_curve_1.0_shift.csv")


# cal aucc =================
SL_aucc = np.sum(direct_ratio_SL_aucc_list['delta_reward'].values) / (direct_ratio_SL_aucc_list['delta_reward'].values[-1] * 201)
XL_aucc = np.sum(direct_ratio_XL_aucc_list['delta_reward'].values) / (direct_ratio_XL_aucc_list['delta_reward'].values[-1] * 201)
GRF_aucc = np.sum(grf['delta_reward'].values) / (grf['delta_reward'].values[-1] * 201)


DR_aucc = np.sum(dr['delta_reward'].values) / (dr['delta_reward'].values[-1] * 201)
DR_MC_aucc = np.sum(dr_mc['delta_reward'].values) / (dr_mc['delta_reward'].values[-1] * 201)


DRP_aucc = np.sum(DRP_avg_aucc_cost_curve['delta_reward'].values) / (DRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)
DRP_MC_aucc = np.sum(drp_mc['delta_reward'].values) / (drp_mc['delta_reward'].values[-1] * 201)

rDRP_aucc = np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)


# output data results ================

print(f"TPM-SL: {SL_aucc:.4f}")
print(f"TPM-XL: {XL_aucc:.4f}")
print(f"TPM-CF: {GRF_aucc:.4f}")


print(f"DR: {DR_aucc:.4f}")
print(f"DR_MC: {DR_MC_aucc:.4f}")


print(f"DRP: {DRP_aucc:.4f}")
print(f"DRP_MC: {DRP_MC_aucc:.4f}")

print(f"rDRP: {rDRP_aucc:.4f}")
# improve = 100*(rDRP_aucc - DRP_aucc)/DRP_aucc
# print(f"{improve:.2f}%")

# np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)

x_index = DRP_avg_aucc_cost_curve['delta_cost'].values
y_random = DRP_avg_aucc_cost_curve['delta_reward'].values[-1] / x_index[-1] * x_index

x_normalization = x_index[-1]
y_normalization = DRP_avg_aucc_cost_curve['delta_reward'].values[-1]


# random ===================================
plt.plot(x_index / x_normalization, y_random / y_normalization, color='#000000', label='Random', linewidth=1.5)

# TPM-SL
plt.plot(x_index / x_normalization, direct_ratio_SL_aucc_list['delta_reward'].values / y_normalization, color='#1f77b4', label='TPM-SL', linewidth=1.5)


# TPM-XL
plt.plot(x_index / x_normalization, direct_ratio_XL_aucc_list['delta_reward'].values / y_normalization, color='#808000', label='TPM-XL', linewidth=1.5)


# TPM-CF
plt.plot(x_index / x_normalization, grf['delta_reward'].values / y_normalization, color='#800080', label='TPM-CF', linewidth=1.5)


# DR
plt.plot(x_index / x_normalization, dr['delta_reward'].values / y_normalization, color='#d62728', label='DR', linewidth=1.5)

# DR_MC
plt.plot(x_index / x_normalization, dr_mc['delta_reward'].values / y_normalization, color='#17becf', label='DR-MC', linewidth=1.5)


# DRP
plt.plot(x_index / x_normalization, DRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#FBB454', label='DRP', linewidth=1.5)


# DRP_MC
plt.plot(x_index / x_normalization, drp_mc['delta_reward'].values / y_normalization, color='#e377c2', label='DRP-MC', linewidth=1.5)


# rDPR
plt.plot(x_index / x_normalization, rDRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#40a368', label='rDRP', linewidth=1.5)


plt.title('Sufficient data and Covariate shift')


plt.xlabel('Incremental cost', fontsize=12, fontweight='bold')
plt.ylabel('Incremental reward', fontsize=12, fontweight='bold')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend()
plt.grid(True)
plt.tight_layout()


# Save and display the figure

plt.savefig('../figure/b.pdf', format='pdf', bbox_inches = 'tight')
plt.show()
# Out:
# TPM-SL: 0.6824
# TPM-XL: 0.6108
# TPM-CF: 0.6817
# DR: 0.6757
# DR_MC: 0.6988
# DRP: 0.7263
# DRP_MC: 0.7265
# rDRP: 0.7382

# %% [markdown]
# ## Fig (c) and aucc value

# %%
# output pic

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# read input csv ==================
direct_ratio_SL_aucc_list = pd.read_csv("../figure/C_direct_ratio_SL_aucc_list.csv")
direct_ratio_XL_aucc_list = pd.read_csv("../figure/C_direct_ratio_XL_aucc_list.csv")

grf = pd.read_csv("../figure/C_grf_aucc_list.csv")

dr = pd.read_csv("../figure/c_DR_avg_aucc_cost_curve_1.0.csv")
dr_mc = pd.read_csv("../figure/c_DR_MC_avg_aucc_cost_curve_1.0.csv")

DRP_avg_aucc_cost_curve = pd.read_csv("../figure/DRP_avg_aucc_cost_curve_0.15.csv")
drp_mc = pd.read_csv("../figure/c_DRP_MC_avg_aucc_cost_curve_0.15.csv")


rDRP_avg_aucc_cost_curve = pd.read_csv("../figure/rDRP_avg_aucc_cost_curve_0.15.csv")


# cal aucc =================
SL_aucc = np.sum(direct_ratio_SL_aucc_list['delta_reward'].values) / (direct_ratio_SL_aucc_list['delta_reward'].values[-1] * 201)
XL_aucc = np.sum(direct_ratio_XL_aucc_list['delta_reward'].values) / (direct_ratio_XL_aucc_list['delta_reward'].values[-1] * 201)
GRF_aucc = np.sum(grf['delta_reward'].values) / (grf['delta_reward'].values[-1] * 201)


DR_aucc = np.sum(dr['delta_reward'].values) / (dr['delta_reward'].values[-1] * 201)
DR_MC_aucc = np.sum(dr_mc['delta_reward'].values) / (dr_mc['delta_reward'].values[-1] * 201)


DRP_aucc = np.sum(DRP_avg_aucc_cost_curve['delta_reward'].values) / (DRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)
DRP_MC_aucc = np.sum(drp_mc['delta_reward'].values) / (drp_mc['delta_reward'].values[-1] * 201)

rDRP_aucc = np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)


# output data results ================

print(f"TPM-SL: {SL_aucc:.4f}")
print(f"TPM-XL: {XL_aucc:.4f}")
print(f"TPM-CF: {GRF_aucc:.4f}")


print(f"DR: {DR_aucc:.4f}")
print(f"DR_MC: {DR_MC_aucc:.4f}")


print(f"DRP: {DRP_aucc:.4f}")
print(f"DRP_MC: {DRP_MC_aucc:.4f}")

print(f"rDRP: {rDRP_aucc:.4f}")
# improve = 100*(rDRP_aucc - DRP_aucc)/DRP_aucc
# print(f"{improve:.2f}%")

# np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)

x_index = DRP_avg_aucc_cost_curve['delta_cost'].values
y_random = DRP_avg_aucc_cost_curve['delta_reward'].values[-1] / x_index[-1] * x_index

x_normalization = x_index[-1]
y_normalization = DRP_avg_aucc_cost_curve['delta_reward'].values[-1]


# random ===================================
plt.plot(x_index / x_normalization, y_random / y_normalization, color='#000000', label='Random', linewidth=1.5)

# TPM-SL
plt.plot(x_index / x_normalization, direct_ratio_SL_aucc_list['delta_reward'].values / y_normalization, color='#1f77b4', label='TPM-SL', linewidth=1.5)


# TPM-XL
plt.plot(x_index / x_normalization, direct_ratio_XL_aucc_list['delta_reward'].values / y_normalization, color='#808000', label='TPM-XL', linewidth=1.5)


# TPM-CF
plt.plot(x_index / x_normalization, grf['delta_reward'].values / y_normalization, color='#800080', label='TPM-CF', linewidth=1.5)


# DR
plt.plot(x_index / x_normalization, dr['delta_reward'].values / y_normalization, color='#d62728', label='DR', linewidth=1.5)

# DR_MC
plt.plot(x_index / x_normalization, dr_mc['delta_reward'].values / y_normalization, color='#17becf', label='DR-MC', linewidth=1.5)


# DRP
plt.plot(x_index / x_normalization, DRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#FBB454', label='DRP', linewidth=1.5)


# DRP_MC
plt.plot(x_index / x_normalization, drp_mc['delta_reward'].values / y_normalization, color='#e377c2', label='DRP-MC', linewidth=1.5)


# rDPR
plt.plot(x_index / x_normalization, rDRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#40a368', label='rDRP', linewidth=1.5)


plt.title('Insufficient data and No covariate shift')


plt.xlabel('Incremental cost', fontsize=12, fontweight='bold')
plt.ylabel('Incremental reward', fontsize=12, fontweight='bold')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend()
plt.grid(True)
plt.tight_layout()


# Save and display the figure

plt.savefig('../figure/c.pdf', format='pdf', bbox_inches = 'tight')
plt.show()
# Out:
# TPM-SL: 0.5772
# TPM-XL: 0.5797
# TPM-CF: 0.5875
# DR: 0.6155
# DR_MC: 0.6203
# DRP: 0.6222
# DRP_MC: 0.6333
# rDRP: 0.6509

# %% [markdown]
# ## Fig (d) and aucc value

# %%
# output pic

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# read input csv ==================
direct_ratio_SL_aucc_list = pd.read_csv("../figure/D_direct_ratio_SL_aucc_list.csv")
direct_ratio_XL_aucc_list = pd.read_csv("../figure/D_direct_ratio_XL_aucc_list.csv")

grf = pd.read_csv("../figure/D_grf_aucc_list.csv")

dr = pd.read_csv("../figure/d_DR_avg_aucc_cost_curve_1.0.csv")
dr_mc = pd.read_csv("../figure/d_DR_MC_avg_aucc_cost_curve_1.0.csv")

DRP_avg_aucc_cost_curve = pd.read_csv("../figure/DRP_avg_aucc_cost_curve_0.15_shift.csv")
drp_mc = pd.read_csv("../figure/d_DRP_MC_avg_aucc_cost_curve_0.15_shift.csv")


rDRP_avg_aucc_cost_curve = pd.read_csv("../figure/rDRP_avg_aucc_cost_curve_0.15_shift.csv")


# cal aucc =================
SL_aucc = np.sum(direct_ratio_SL_aucc_list['delta_reward'].values) / (direct_ratio_SL_aucc_list['delta_reward'].values[-1] * 201)
XL_aucc = np.sum(direct_ratio_XL_aucc_list['delta_reward'].values) / (direct_ratio_XL_aucc_list['delta_reward'].values[-1] * 201)
GRF_aucc = np.sum(grf['delta_reward'].values) / (grf['delta_reward'].values[-1] * 201)


DR_aucc = np.sum(dr['delta_reward'].values) / (dr['delta_reward'].values[-1] * 201)
DR_MC_aucc = np.sum(dr_mc['delta_reward'].values) / (dr_mc['delta_reward'].values[-1] * 201)


DRP_aucc = np.sum(DRP_avg_aucc_cost_curve['delta_reward'].values) / (DRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)
DRP_MC_aucc = np.sum(drp_mc['delta_reward'].values) / (drp_mc['delta_reward'].values[-1] * 201)

rDRP_aucc = np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)


# output data results ================

print(f"TPM-SL: {SL_aucc:.4f}")
print(f"TPM-XL: {XL_aucc:.4f}")
print(f"TPM-CF: {GRF_aucc:.4f}")


print(f"DR: {DR_aucc:.4f}")
print(f"DR_MC: {DR_MC_aucc:.4f}")


print(f"DRP: {DRP_aucc:.4f}")
print(f"DRP_MC: {DRP_MC_aucc:.4f}")

print(f"rDRP: {rDRP_aucc:.4f}")
# improve = 100*(rDRP_aucc - DRP_aucc)/DRP_aucc
# print(f"{improve:.2f}%")

# np.sum(rDRP_avg_aucc_cost_curve['delta_reward'].values) / (rDRP_avg_aucc_cost_curve['delta_reward'].values[-1] * 201)

x_index = DRP_avg_aucc_cost_curve['delta_cost'].values
y_random = DRP_avg_aucc_cost_curve['delta_reward'].values[-1] / x_index[-1] * x_index

x_normalization = x_index[-1]
y_normalization = DRP_avg_aucc_cost_curve['delta_reward'].values[-1]


# random ===================================
plt.plot(x_index / x_normalization, y_random / y_normalization, color='#000000', label='Random', linewidth=1.5)

# TPM-SL
plt.plot(x_index / x_normalization, direct_ratio_SL_aucc_list['delta_reward'].values / y_normalization, color='#1f77b4', label='TPM-SL', linewidth=1.5)


# TPM-XL
plt.plot(x_index / x_normalization, direct_ratio_XL_aucc_list['delta_reward'].values / y_normalization, color='#808000', label='TPM-XL', linewidth=1.5)


# TPM-CF
plt.plot(x_index / x_normalization, grf['delta_reward'].values / y_normalization, color='#800080', label='TPM-CF', linewidth=1.5)


# DR
plt.plot(x_index / x_normalization, dr['delta_reward'].values / y_normalization, color='#d62728', label='DR', linewidth=1.5)

# DR_MC
plt.plot(x_index / x_normalization, dr_mc['delta_reward'].values / y_normalization, color='#17becf', label='DR-MC', linewidth=1.5)


# DRP
plt.plot(x_index / x_normalization, DRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#FBB454', label='DRP', linewidth=1.5)


# DRP_MC
plt.plot(x_index / x_normalization, drp_mc['delta_reward'].values / y_normalization, color='#e377c2', label='DRP-MC', linewidth=1.5)


# rDPR
plt.plot(x_index / x_normalization, rDRP_avg_aucc_cost_curve['delta_reward'].values / y_normalization, color='#40a368', label='rDRP', linewidth=1.5)


plt.title('Insufficient data and Covariate shift')


plt.xlabel('Incremental cost', fontsize=12, fontweight='bold')
plt.ylabel('Incremental reward', fontsize=12, fontweight='bold')

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend()
plt.grid(True)
plt.tight_layout()


# Save and display the figure

plt.savefig('../figure/d.pdf', format='pdf', bbox_inches = 'tight')
plt.show()
# Out:
# TPM-SL: 0.5851
# TPM-XL: 0.4215
# TPM-CF: 0.5358
# DR: 0.4465
# DR_MC: 0.5326
# DRP: 0.5411
# DRP_MC: 0.5907
# rDRP: 0.6087
